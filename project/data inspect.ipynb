# %%
import pandas as pd
import numpy as np

# %%
user = pd.read_csv("data/user_profile_table.csv")
user.head()
user.describe()
# Out:
#             user_id           sex          city
# count  28041.000000  28041.000000  2.804100e+04
# mean   14021.000000      0.516708  6.342137e+06
# std     8094.883785      0.499730  1.356857e+05
# min        1.000000      0.000000  6.081949e+06
# 25%     7011.000000      0.000000  6.281949e+06
# 50%    14021.000000      1.000000  6.411949e+06
# 75%    21031.000000      1.000000  6.412149e+06
# max    28041.000000      1.000000  6.581949e+06

# %%
shibor = pd.read_csv("data/mfd_bank_shibor.csv",index_col=0,parse_dates=True)
shibor.head()
# Out:
#             Interest_O_N  Interest_1_W  Interest_2_W  Interest_1_M  \
# mfd_date
# 2013-07-01         4.456         5.423         6.040        6.8800
# 2013-07-02         3.786         4.750         5.074        5.8000
# 2013-07-03         3.400         4.242         4.658        5.2000
# 2013-07-04         3.348         3.938         4.464        5.1020
# 2013-07-05         3.380         3.816         4.295        4.7885
#
#             Interest_3_M  Interest_6_M  Interest_9_M  Interest_1_Y
# mfd_date
# 2013-07-01         5.295        4.2390        4.2820        4.4125
# 2013-07-02         5.211        4.2344        4.2808        4.4070
# 2013-07-03         5.148        4.2300        4.2796        4.4022
# 2013-07-04         5.029        4.2287        4.2776        4.4000
# 2013-07-05         4.939        4.2273        4.2749        4.4000

# %%
share = pd.read_csv("data/mfd_day_share_interest.csv",index_col=0,parse_dates=True)
share.head()
# Out:
#             mfd_daily_yield  mfd_7daily_yield
# mfd_date
# 2013-07-01           1.5787             6.307
# 2013-07-02           1.5461             6.174
# 2013-07-03           1.4670             6.034
# 2013-07-04           1.4223             5.903
# 2013-07-05           1.3845             5.739

# %%
balance = pd.read_csv("user_balance_table.csv",index_col="report_date",parse_dates=True)
balance.head()
# Out:
#              user_id  tBalance  yBalance  total_purchase_amt  \
# report_date
# 2014-08-05         1     20385     20383                   2
# 2014-08-08         1     20391     20389                   2
# 2014-08-11         1     20397     20395                   2
# 2014-08-14         1     20403     20401                   2
# 2014-08-17         1     20409     20407                   2
#
#              direct_purchase_amt  purchase_bal_amt  purchase_bank_amt  \
# report_date
# 2014-08-05                     0                 0                  0
# 2014-08-08                     0                 0                  0
# 2014-08-11                     0                 0                  0
# 2014-08-14                     0                 0                  0
# 2014-08-17                     0                 0                  0
#
#              total_redeem_amt  consume_amt  transfer_amt  tftobal_amt  \
# report_date
# ...

# %%
temp = balance.groupby("report_date").apply(lambda x:x.sum())

# %%
temp.consume_amt.plot()

# %%
temp
# Out:
#                  user_id      tBalance      yBalance  total_purchase_amt  \
# report_date
# 2013-07-01     6305946.0  2.523279e+08  2.253645e+08          32488348.0
# 2013-07-02     6776722.0  2.788107e+08  2.523279e+08          29037390.0
# 2013-07-03     7025037.0  3.001276e+08  2.788107e+08          27270770.0
# 2013-07-04     7334624.0  3.120381e+08  3.001276e+08          18321185.0
# 2013-07-05     7603689.0  3.209232e+08  3.120381e+08          11648749.0
# ...                  ...           ...           ...                 ...
# 2014-08-27   175954982.0  2.017168e+10  2.033765e+10         302194801.0
# 2014-08-28   176340561.0  2.011887e+10  2.017168e+10         245082751.0
# 2014-08-29   177016484.0  2.011267e+10  2.011887e+10         267554713.0
# 2014-08-30   177040421.0  2.011600e+10  2.011267e+10         199708772.0
# 2014-08-31   177243675.0  2.009815e+10  2.011600e+10         275090213.0
#
#              direct_purchase_amt  purchase_bal_amt  purchase_bank_amt  \
# ...
